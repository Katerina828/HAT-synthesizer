# %%
#import MySythesizerdemo

#from MySythesizerdemo import *


import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # show boxplot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# Fixing random state for reproducibility
np.random.seed(19680801)


# generate some random test data
#all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]
x1=[0.95,1.12,1.69,1.14,0.52,0.86,1.24,1.94,0.79,1.62,1.5,0.82]
x2 = [1.86,2.45,2.29,1.26,1.67,1.2,1.68,1.28,1.99,1.15,1.46,1.52]
x3 = [3.31,3.66,3.19,3.07,3.27,2.68,3.72,2,2.61,2.1,2.66,3.49]
x4 = [8.08,6.99,5.57,11.51,7.79,7.38,10.78,4.59,8.69,5.9,8.87,14.72]
x5 = [8.54,7.81,6.4,11.62,11.51,6.27,8.46,4.04,7.16,4.37,6.39,9.77]
all_data=[x1,x2,x3,x4,x5]
# plot violin plot
axs[0].violinplot(all_data,
                  showmeans=False,
                  showmedians=True)
axs[0].set_title('Violin plot')

# plot box plot
axs[1].boxplot(all_data)
axs[1].set_title('Box plot')

# adding horizontal grid lines
for ax in axs:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 1 for y in range(len(all_data))])
    ax.set_xlabel('Five samples')
    ax.set_ylabel('Counts')

# add x-tick labels
plt.setp(axs, xticks=[y + 1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4','x5'])
plt.show()

# %%
import pandas as pd
x1=[0.95,1.12,1.69,1.14,0.52,0.86,1.24,1.94,0.79,1.62,1.5,0.82,0.83,0.83,2.2,1.46,2.2,0.61,0.78,1.82]
x2 = [1.86,2.45,2.29,1.26,1.67,1.2,1.68,1.28,1.99,1.15,1.46,1.52,1.76,1.35,1.51,1.46,2.08,1.29,1.33,1.13]
x3 = [3.31,3.66,3.19,3.07,3.27,2.68,3.72,2,2.61,2.1,2.66,3.49,2.11,4,3.08,2.4,3.44,3.66,3.55,1.56]
x4 = [8.08,6.99,5.57,11.51,7.79,7.38,10.78,4.59,8.69,5.9,8.87,14.72,8.53,10.56,8.49,9.15,4.91,10.33,9.89,7.06]
x5 = [8.54,7.81,6.4,11.62,11.51,6.27,8.46,4.04,7.16,4.37,6.39,9.77,2.57,9.09,5.84,9.25,4.75,6.54,7.72,4.6]
name =['x1','x2','x3','x4','x5']
all_data={1800:x1,
          7102:x2,
          10655:x3,
          13538:x4,
          23269:x5}

data=pd.DataFrame(all_data)
#data['type']=1
data_n = data.stack()
df1 = data_n.reset_index(drop=True, level=0)
df1 = df1.reset_index()
df1 = df1.rename(columns={"index":"Index",0:"Counts"})
df1['type']="In"

# %%
import pandas as pd
x1=[0.75,1.71,1.04,1.05,0.97,1.87,0.62,1.36,1.96,1.21,2.14,1.65,1.24,1.01,1.47,0.88,1.89,1.4,1.58,0.83]
x2 = [1.23,1.69,1.71,3.57,1.7,1.86,1.64,1.93,1.35,1.36,1.76,1.61,1.86,1.64,1.56,1.96,1.37,0.98,1.23,1.28]
x3 = [3.39,3.44,2.02,2.88,3.29,2.09,2.73,3.13,4.12,3.02,1.87,2.09,1.92,2.61,3.62,2.67,3.03,3.21,2.24,2.14]
x4 = [14.2,5.61,7.01,4.11,15.34,5.41,7.12,6.12,6.34,8.45,11.82,7.58,5.82,8.46,14.92,9.77,5.34,5.78,10.71,10.47]
x5 = [3.69,6.05,7.99,7.68,8.14,4.31,5.4,7.48,6.53,6.02,7.06,4.26,4.4,3.68,6.65,6.5,7.04,7.23,4.54,8.05]
all_data={1800:x1,
          7102:x2,
          10655:x3,
          13538:x4,
          23269:x5}

data=pd.DataFrame(all_data)
#data['type']=1
data_n = data.stack()
df2 = data_n.reset_index(drop=True, level=0)
df2 = df2.reset_index()
df2 = df2.rename(columns={"index":"Index",0:"Counts"})
df2['type']="Out"

# %%
df = pd.concat([df1,df2],axis=0)

# %%
tem_with = pd.read_csv("./exp_result/lawsch_with_target1.csv")
tem_with2 = pd.read_csv("./exp_result/lawsch_with_target2.csv")

# %%
tem_with = tem_with.rename(columns={"WithoutTg": "Counts"})
tem_with = tem_with.drop(columns='seed')

# %%
tem_with.head()
# Out:
#    Counts  target  withTg
# 0    0.00    7587    True
# 1    0.61    7587    True
# 2    1.20    7587    True
# 3    1.56    7587    True
# 4    0.82    7587    True

# %%
tem_7587_without = df[df['target']==7587]
tem_7587_without['withTg']=False
tem_7587_without = tem_7587_without.rename(columns={"WithoutTg": "Counts"})
tem_7587_without.head()
# Out:
# C:\Users\HAT\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Counts  target  withTg
# 0    1.22    7587   False
# 1    0.50    7587   False
# 2    1.45    7587   False
# 3    0.79    7587   False
# 4    0.63    7587   False

# %%
df= pd.concat([tem_with,tem_7587_without])

# %%
sns.boxplot(x='target',y='Counts',hue="withTg", color='gray',data=df)

# %%
tem = pd.read_csv("./exp_result/lawsch_without_target1.csv")
tem2 = pd.read_csv("./exp_result/lawsch_without_target1_2.csv")
tem3 = pd.read_csv("./exp_result/lawsch_without_target2.csv")
tem4 = pd.read_csv("./exp_result/lawsch_without_target3.csv")
df = pd.concat([tem,tem2,tem3,tem4],axis=0)
df.target.unique()
# Out:
# array([ 6165, 11169,  7587, 33430, 15336,  3662], dtype=int64)

# %%
sns.set(style="whitegrid", color_codes=True,font_scale=1.5)
fig, ax = plt.subplots(figsize=(7, 6), constrained_layout=True)
#fig = plt.figure(figsize=(7, 6))
sns.boxplot(x='Index',y='Counts',hue="type", color='gray',data=df,ax=ax)
sns.despine(offset=10, trim=True)
plt.xlabel('Five samples',fontsize=25)
plt.ylabel('Counts',fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.setp(ax, xticklabels=['$\mathbf{x}_1$', '$\mathbf{x}_2$', '$\mathbf{x}_3$', '$\mathbf{x}_4$','$\mathbf{x}_5$'])
plt.tight_layout()
#plt.savefig("./figure/"+"adv/"+ "adult_counts.png",dpi=400)

# %%
sns.set(style="whitegrid", color_codes=True,font_scale=1.5)
fig, ax = plt.subplots(figsize=(7, 6), constrained_layout=True)
#fig = plt.figure(figsize=(7, 6))
sns.boxplot(x='Index',y='Counts',hue="type", color='gray',data=df,ax=ax)
sns.despine(offset=10, trim=True)
plt.xlabel('Five samples',fontsize=25)
plt.ylabel('Counts',fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.setp(ax, xticklabels=['$\mathbf{x}_1$', '$\mathbf{x}_2$', '$\mathbf{x}_3$', '$\mathbf{x}_4$','$\mathbf{x}_5$'])
plt.tight_layout()
plt.savefig("./figure/"+"adv/"+ "adult_counts.png",dpi=400)
# Out:
# C:\Users\HAT\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   if sys.path[0] == '':

# %%
DP1_1800=[0.97,2.06,0.48,1.33,0.38,2.09,1.53,0.8,1.69,3.39,1.88,0.97,1.01,1.71,1.73,2.54,2.26,0.61,3.74,2.1]
DP1_7102 =[1.51,1.23,0.92,1.76,2.07,1.2,1.49,0.48,0.87,1.57,1.13,0.94,2.19,2.21,1.34,1.51,2.37,2.55,0.87,1.58]
DP1_10655 =[6.27,3.46,3.27,3.14,3.64,3.13,1.94,5.24,3.01,1.55,1.73,2.77,3.79,2.68,3.15,2.58,3.28,2.73,3.06,2.99]
DP1_13538=[5.04,5.83,10.33,4.15,7.69,8.76,10.95,17.6,6.93,2.64,6.1,13.69,4.67,8.12,5.2,9.12,10.45,4.24,2.77,10.03]
DP1_23269 =[9.16,5.68,13.07,2.02,9.38,5.89,3.87,8.19,3.44,0.99,3.92,9.77,3.78,14.38,1.1,8.39,7.17,4.9,1.59,8.53]

DP2_1800=[1.39,0.9,0.48,0.46,2.1,0.48,2.24,2.17,3.17,1.16,0.78,0.78,1.18,2.29,0.75,1.6,0.36,0.17,0.95]

# %%
x= pd.read_csv("exp.csv")

# %%
x_= x.set_index(["DP","TargetIdx"]).stack().reset_index(drop=True, level=-1).reset_index().rename(columns={0: "Counts"})

# %%
x_.loc[x_["DP"] == 1.5, "DP"] = 9.1

# %%
x_.loc[x_["DP"] == 2.0, "DP"] = 6.2
x_.loc[x_["DP"] == 2.5, "DP"] = 4.7
x_.loc[x_["DP"] == 3.0, "DP"] = 3.8
x_.loc[x_["DP"] == 4.0, "DP"] = 2.8

# %%
x_.head()
# Out:
#     DP  TargetIdx  Counts
# 0  9.1       1800    0.97
# 1  9.1       1800    2.06
# 2  9.1       1800    0.48
# 3  9.1       1800    1.33
# 4  9.1       1800    0.38

# %%
sns.set(style="ticks", palette="pastel")
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15, 4))

#f, axes = plt.subplots(1, 5)
index = [1800,7102,10655,13538,23269]
for i,idx in enumerate(index):
    target = x_[x_["TargetIdx"]==idx]
#sns.boxplot(x='Counts',hue="DP",col = 'TargetIdx',data=x_)
    sns.boxplot(x="DP",y="Counts", 
                data=target,ax=axes[i%5]);
    axes[i%5].set_title("index ="+str(idx),fontsize=15)
    axes[i%5].set_xlabel("DP, epsilon",fontsize=15)
    if i==0:
        axes[i%5].set_ylabel('Frequency', fontsize=15)
    else:
        axes[i%5].set_ylabel('')
    
#col="TargetIdx",
#sns.despine(offset=10, trim=True)
plt.tight_layout()
plt.savefig("./figure/"+"adv/"+ "adult_DP_freq.png",dpi=600)

# %%
df2 = df2.rename(columns={"index":"Index",0:"Counts"})
df2['type']="Out"

# %%
76.07-(23.5-21.3)/(26.73-21.3)*(76.07-73.28)
# Out:
# 74.9396132596685

# %%
sns.set(style="whitegrid")
x= np.arange(1,11)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))

y_adult_pre = [86.56,90.12,91.11,92.62,93.09,92.47,92.51,92.69,93.1,94.92]
y_adult_rec = [23.51,23.51,24.01,22.65,23.62,23.04,24.1,23.5,23.84,23.89]

y_lawsch_pre = [60.6,73.14,74.17,74.94,76,78.03,76.74,77,77.12,78.34]
y_lawsch_rec = [23.59,23.5,23.86,23.5,23.63,22.34,23.33,24.84,23.38,22.52]

y_compas_pre = [70.83,74.96,76.44,78.49,80.2,79.8,80.37,81.04,81.06,80]
y_compas_rec = [47.89,43.91,43.16,42.65,45.74,45.61,42.87,44.21,46.61,46.05]

ax1.plot(x, y_adult_pre, 'o-',markeredgewidth='5',label='Adult')
ax1.plot(x, y_lawsch_pre, 's-.',markeredgewidth='5',label='Lawsch')
ax1.plot(x, y_compas_pre, 'o-.',markeredgewidth='5',label='Compas')
ax1.set_title("Precition",fontsize=20)
ax1.set_xlabel('Synthetic Dataset Size',fontsize=20)
ax1.set_ylabel('probability',fontsize=20)
ax1.legend(loc='lower right',fontsize=20)

ax2.plot(x, y_adult_rec, 'o-',markeredgewidth='6',label='Adult')
ax2.plot(x, y_lawsch_rec, 's-.',markeredgewidth='6',label='Lawsch')
ax2.plot(x, y_compas_rec, 'o-.',markeredgewidth='6',label='Compas')
ax2.set_title("Recal",fontsize=20)
ax2.set_xlabel('Synthetic Dataset Size',fontsize=20)
ax2.set_ylabel('probability',fontsize=20)
ax2.set_ylim(0, 50)
ax2.legend(loc='lower right',fontsize=20)
ax1.tick_params(labelsize=15)
ax2.tick_params(labelsize=15)

plt.tight_layout()
plt.savefig("./figure/"+"adv/"+ "pre_recal.eps",dpi=600)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
